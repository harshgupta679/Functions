# %% [markdown]
# # FUNCTIONS
#
# 1 -  What is the difference between a function and a method in Python?
#
# >- Function is a block of code that performs a task and is defined using def. It can be called independently.
#
# EXAMPLE -

# %%
def greet():
    print("Hello")
greet()

# %% [markdown]
# >- Method is a function associated with an object and is called on that object (usually with a dot).
#
# Example:

# %%
name = "ajay"
print(name.upper())  # upper() is a method

# %% [markdown]
# 2 - Explain the concept of function arguments and parameters in Python.
#
# >- Parameters are variables listed inside the parentheses in the function definition.
#
# Example:

# %%
def greet(name):  # 'name' is a parameter
    print("Hello", name)

# %% [markdown]
# >- Arguments are the actual values passed to the function when it is called.
#
# Example:

# %%
greet("ajay")  # "ajay" is an argument

# %% [markdown]
# 3-  What are the different ways to define and call a function in Python?
#
# >- Different Ways to Define and Call a Function in Python:

# %%
#  Normal Function Definition and Call:

def add(a, b):
    return a + b
print(add(2, 3))  # Output: 5



# Default Arguments:

def greet(name="User"):
    print("Hello", name)
greet()           # Output: Hello User



#Keyword Arguments:

def intro(name, age):
    print(name, age)
intro(age=25, name="Harsh")



#   Variable-length Arguments (*args, kwargs):

def total(*numbers):
    return sum(numbers)
print(total(1, 2, 3))  # Output: 6



#  Lambda Function (anonymous):

square = lambda x: x * x
print(square(4))  # Output: 16

# %% [markdown]
# 4-  What is the purpose of the `return` statement in a Python function?
#
# >- Purpose of the return Statement in Python:
#
# - The return statement is used to send a value back from a function to the caller.
#
# - It ends the function's execution and outputs the result.

# %%
def multiply(a, b):
    return a * b

result = multiply(4, 5)
print(result)  # Output: 20

# %% [markdown]
# 5- What are iterators in Python and how do they differ from iterables?
#
# >- Iterators vs Iterables in Python:
#
# - Iterable is any object capable of returning its members one at a time (e.g., list, tuple, string).
#
# - Iterator is an object that uses __next__() to get items from an iterable one at a time.
#
# Example:

# %%
nums = [1, 2, 3]       # Iterable
it = iter(nums)        # Iterator created from iterable
print(next(it))        # Output: 1

# %% [markdown]
# 6-  Explain the concept of generators in Python and how they are defined.
#
# >- Generators in Python:
#
# - Generators are functions that return an iterator using the yield keyword instead of return.
#
# - They generate values one at a time and save memory.

# %%
def countdown(n):
    while n > 0:
        yield n
        n -= 1

for num in countdown(3):
    print(num)  # Output: 3 2 1

# %% [markdown]
# 7-  What are the advantages of using generators over regular functions?
#
# >- Advantages of Generators over Regular Functions:
#
# -  Memory Efficient: They yield one item at a time, so no need to store the entire sequence in memory.
#
# - Lazy Evaluation: Values are generated only when needed.
#
# - Cleaner Code: Useful for large data streams or infinite sequences.
#
# # Example:

# %%
def gen():
    for i in range(1000000):
        yield i

# %% [markdown]
# 8- What is a lambda function in Python and when is it typically used?
#
# >- Lambda Function in Python:
#
# -  lambda function is an anonymous, one-line function defined using the lambda keyword.
#
# - It's typically used for short, throwaway functions.
#
# Syntax:

# %%
square = lambda x: x * x
print(square(5))  # Output: 25

# %% [markdown]
# 9- Explain the purpose and usage of the `map()` function in Python.
#
# >- Purpose of map() in Python:
#
# - map() applies a given function to all items in an iterable (like a list) and returns a map object (an iterator).
#
# EXAMPLE -

# %%
nums = [1, 2, 3]
squared = map(lambda x: x * x, nums)
print(list(squared))  # Output: [1, 4, 9]

# %% [markdown]
# 10-  What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# >- Difference between map(), reduce(), and filter() in Python:
#
# - map():
# Applies a function to all items in an iterable and returns an iterator of the results.
#
# Example:

# %%
nums = [1, 2, 3]
result = map(lambda x: x * x, nums)
print(list(result))  # Output: [1, 4, 9]

# %% [markdown]
# >- reduce():   Applies a function cumulatively to the items of an iterable, reducing it to a single value.
# (Needs to be imported from functools)
#
# Example:

# %%
from functools import reduce
nums = [1, 2, 3]
result = reduce(lambda x, y: x + y, nums)
print(result)  # Output: 6

# %% [markdown]
# - filter():Filters items in an iterable by applying a function that returns True or False. It returns an iterator of items where the function returns True.
#
# Example:

# %% [markdown]
# nums = [1, 2, 3, 4]
# result = filter(lambda x: x % 2 == 0, nums)
# print(list(result))  # Output: [2, 4]

# %% [markdown]
# 11-  Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given   list:[47,11,42,13];
#
# >- To simulate the internal mechanism of the reduce() function for the sum operation on the list [47, 11, 42, 13], let's break it down step by step. The reduce() function applies the operation (in this case, addition) cumulatively to the elements of the list.
#
# Step-by-Step Internal Mechanism:
# Given List:
#
# csharp
#
# [47, 11, 42, 13]
# Function to Apply:
# Let's use a simple addition function:
#
#
# lambda x, y: x + y
# First Step:
# Initial Values:
#
# The first two elements of the list are 47 and 11.
#
# Apply the function:
#
#
# 47 + 11 = 58
# Intermediate result: 58
#
# Second Step:
# Using the Intermediate Result (58) with the Next Element (42):
#
# Now, take the result from the first step (58) and apply the function with the next element in the list, which is 42.
#
#
# 58 + 42 = 100
# Intermediate result: 100
#
# Third Step:
# Using the Intermediate Result (100) with the Next Element (13):
#
# Take the result from the second step (100) and apply the function with the final element in the list, which is 13.
#
#
# 100 + 13 = 113
# Final result: 113
#
# Final Result:
# The sum of the list [47, 11, 42, 13] is 113.
#
# Summary:
# First operation: 47 + 11 = 58
#
# Second operation: 58 + 42 = 100
#
# Third operation: 100 + 13 = 113
#
# Thus, the result of using reduce() with addition on the list [47, 11, 42, 13] is 113.

# %% [markdown]
# # Practical Questions

# %%
#  1-  Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

# Solution :

def sum_even_numbers(numbers):
    # Filter the even numbers and sum them
    return sum(num for num in numbers if num % 2 == 0)

# Example usage:
numbers = [47, 11, 42, 13]
result = sum_even_numbers(numbers)
print(result)  # Output: 42

# %%
# 2-  Create a Python function that accepts a string and returns the reverse of that string.

# Solution :

def reverse_string(s):
    return s[::-1]

# Example usage:
input_string = "Hello, World!"
result = reverse_string(input_string)
print(result)  # Output: "!dlroW ,olleH"

# %%
# 3- Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

# Solution :

def square_numbers(numbers):
    return [num ** 2 for num in numbers]

# Example usage:
input_list = [1, 2, 3, 4, 5]
result = square_numbers(input_list)
print(result)  # Output: [1, 4, 9, 16, 25]

# %%
# 4-  Write a Python function that checks if a given number is prime or not from 1 to 200.

# Solution : def is_prime(num):
    if num <= 1:
        return False
    for i in range(2, int(num**0.5) + 1):  # Check divisibility up to the square root of num
        if num % i == 0:
            return False
    return True

# Check for primes from 1 to 200
primes = [num for num in range(1, 201) if is_prime(num)]
print(primes)

# %%
# 5- Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.

# Solution :

class FibonacciIterator:
    def __init__(self, n):
        self.n = n  # Number of terms in the sequence
        self.a, self.b = 0, 1  # Starting values for Fibonacci sequence
        self.count = 0  # Counter to track how many terms we've generated

    def __iter__(self):
        return self  # Return the iterator object itself

    def __next__(self):
        if self.count < self.n:
            fib_number = self.a
            self.a, self.b = self.b, self.a + self.b  # Update to next Fibonacci numbers
            self.count += 1
            return fib_number
        else:
            raise StopIteration  # Stop the iteration when we reach n terms

# Example usage:
fibonacci = FibonacciIterator(10)  # Generate first 10 Fibonacci numbers
for num in fibonacci:
    print(num)

# %%
# 6 - Write a generator function in Python that yields the powers of 2 up to a given exponent.

# Solution :

def powers_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

# Example usage:
for power in powers_of_two(5):
    print(power)

# %%
# 7 -  Implement a generator function that reads a file line by line and yields each line as a string.

# Solution :

def read_file_line_by_line(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()  # strip() removes leading/trailing whitespace/newlines

# Example usage:
file_path = 'example.txt'  # Replace with the path to your file
for line in read_file_line_by_line(file_path):
    print(line)

# %%
# 8 - Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# Solution :

# List of tuples
tuples_list = [(1, 4), (3, 1), (5, 2), (2, 3)]

# Sort the list based on the second element of each tuple using a lambda function
sorted_list = sorted(tuples_list, key=lambda x: x[1])

# Print the sorted list
print(sorted_list)

# %%
# 9 -  Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# Solution :

# List of temperatures in Celsius
celsius_temperatures = [0, 10, 20, 30, 40, 50]

# Function to convert Celsius to Fahrenheit
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# Using map() to apply the conversion function to each element in the list
fahrenheit_temperatures = map(celsius_to_fahrenheit, celsius_temperatures)

# Convert the result to a list and print it
print(list(fahrenheit_temperatures))

# %%
# 10 -  Create a Python program that uses `filter()` to remove all the vowels from a given string.

# Solution :

# Function to check if a character is not a vowel
def is_not_vowel(char):
    vowels = "aeiouAEIOU"
    return char not in vowels

# Given string
input_string = "Hello, World!"

# Using filter() to remove vowels
filtered_string = filter(is_not_vowel, input_string)

# Convert the result to a string and print it
result = ''.join(filtered_string)
print(result)

# %%
# 11 - Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:


#   Order Number   Book Title and Author                      Quantity   Price per Item
#   34587          Learning Python, Mark Lutz                 4          40.95
#   98762          Programming Python, Mark Lutz              5          56.80
#   77226          Head First Python, Paul Barry              3          32.95
#   88112          Einführung in Python3, Bernd Klein         3          24.99


# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €. Write a Python program using lambda and map.

#  Solution :

# List of orders: [Order Number, Book Title, Quantity, Price per Item]
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Apply lambda and map to generate the desired list of tuples
result = list(map(lambda order: (
    order[0],
    round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0), 2)
), orders))

# Print the result
print(result)
